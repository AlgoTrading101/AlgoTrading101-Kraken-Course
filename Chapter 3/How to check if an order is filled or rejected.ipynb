# %%
import krakenex
from pykrakenapi import KrakenAPI
api = krakenex.API()
kraken = KrakenAPI(api)

# %%
api.load_key('KrakenPass.txt')

# %%
info = kraken.query_orders_info(txid='OJK3LL-FDLS4-AVKLMK')
info.T
# Out:
#                                        OJK3LL-FDLS4-AVKLMK
# closetm                                     1620229755.657
# cost                                                   0.0
# expiretm                                               0.0
# fee                                                    0.0
# limitprice                                     0.000000000
# misc
# oflags                                                fciq
# opentm                                     1620229068.9506
# price                                                  0.0
# reason                                      User requested
# refid                                                 None
# starttm                                                0.0
# status                                            canceled
# stopprice                                      0.000000000
# userref                                                  0
# vol                                                   50.0
# ...
