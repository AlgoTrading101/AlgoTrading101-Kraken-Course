# %%
import krakenex
from pykrakenapi import KrakenAPI

api = krakenex.API()
kraken = KrakenAPI(api)

api.load_key('KrakenPass.txt')

# %%
kraken.get_open_orders().T
# Out:
#                                       OXPHXB-LFIYJ-QDMTJ5
# cost                                                  0.0
# expiretm                                                0
# fee                                                   0.0
# limitprice                                       0.000000
# misc
# oflags                                          fcib,post
# opentm                                         1628180859
# price                                                 0.0
# refid                                                None
# starttm                                                 0
# status                                               open
# stopprice                                        0.000000
# userref                                                 0
# vol                                                  24.0
# vol_exec                                              0.0
# descr_pair                                         ADAUSD
# ...
